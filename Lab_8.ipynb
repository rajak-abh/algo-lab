# %% [markdown]
# <a href="https://colab.research.google.com/github/rajak-abh/algo-lab/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 4, "H": 8},
    "B": {"A": 4, "C": 8, "H": 11},
    "C": {"B": 8, "D": 7, "F": 4, "I": 2},
    "D": {"C": 7, "E": 9, "F": 14},
    "E": {"D": 9, "F": 10},
    "F": {"C": 4, "D": 14, "E": 10, "G": 2},
    "G": {"F": 2, "H": 1, "I": 6},
    "H": {"A": 8, "B": 11, "G": 1, "I": 7},
    "I": {"C": 2, "G": 6, "H": 7}
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
import heapq

def prim_algorithm(graph):
    if not graph:
        return [], 0

    start_vertex = list(graph.keys())[0]
    min_spanning_tree_edges = []  # Stores edges as (u, v, weight)
    visited = {start_vertex}
    min_heap = []

    # Initialize min_heap with all edges connected to the start_vertex
    # Format: (weight, u, v)
    for neighbor, weight in graph[start_vertex].items():
        heapq.heappush(min_heap, (weight, start_vertex, neighbor))

    total_weight = 0

    while min_heap and len(visited) < len(graph):
        weight, u, v = heapq.heappop(min_heap)

        if v not in visited:
            visited.add(v)
            min_spanning_tree_edges.append((u, v, weight))
            total_weight += weight

            # Add all edges from the newly added vertex 'v' to the min_heap
            for neighbor_of_v, weight_of_edge in graph[v].items():
                if neighbor_of_v not in visited:
                    heapq.heappush(min_heap, (weight_of_edge, v, neighbor_of_v))

    return min_spanning_tree_edges, total_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  [('A', 'B', 10), ('B', 'C', 12), ('C', 'D', 18)]
# Minimum Weight:  40

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# The graph has been updated in the cell above (nYNJFvbDYpM3).
# No new input is needed here, just running the algorithm.
graph = {
    "A": {"B": 2, "C": 3},
    "B": {"A": 2, "C": 1, "D": 1},
    "C": {"A": 3, "B": 1, "D": 4, "E": 5},
    "D": {"B": 1, "C": 4, "E": 2},
    "E": {"C": 5, "D": 2}
}

# %%
#run prims algorithm for sample inputimport heapq

graph = {
    "A": {"B": 2, "C": 3},
    "B": {"A": 2, "C": 1, "D": 1},
    "C": {"A": 3, "B": 1, "D": 4, "E": 5},
    "D": {"B": 1, "C": 4, "E": 2},
    "E": {"C": 5, "D": 2}
}

def prim_algorithm(graph):
    if not graph:
        return [], 0

    start_vertex = list(graph.keys())[0]
    min_spanning_tree_edges = []
    visited = {start_vertex}
    min_heap = []

    for neighbor, weight in graph[start_vertex].items():
        heapq.heappush(min_heap, (weight, start_vertex, neighbor))

    total_weight = 0

    while min_heap and len(visited) < len(graph):
        weight, u, v = heapq.heappop(min_heap)

        if v not in visited:
            visited.add(v)
            min_spanning_tree_edges.append((u, v, weight))
            total_weight += weight

            for neighbor_of_v, weight_of_edge in graph[v].items():
                if neighbor_of_v not in visited:
                    heapq.heappush(min_heap, (weight_of_edge, v, neighbor_of_v))

    return min_spanning_tree_edges, total_weight


mst, min_weight = prim_algorithm(graph)

print("Minimum Spanning Tree:", mst)
print("Minimum Weight:", min_weight)
# Out:
# Minimum Spanning Tree: [('A', 'B', 2), ('B', 'C', 1), ('B', 'D', 1), ('D', 'E', 2)]
# Minimum Weight: 6

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal'sgraph = {
graph = {
    "A": {"B": 2, "C": 3},
    "B": {"A": 2, "C": 1, "D": 1},
    "C": {"A": 3, "B": 1, "D": 4, "E": 5},
    "D": {"B": 1, "C": 4, "E": 2},
    "E": {"C": 5, "D": 2}
}

def find(parent, vertex):
    if parent[vertex] != vertex:
        parent[vertex] = find(parent, parent[vertex])
    return parent[vertex]


def union(parent, rank, x, y):
    root_x = find(parent, x)
    root_y = find(parent, y)

    if rank[root_x] < rank[root_y]:
        parent[root_x] = root_y
    elif rank[root_x] > rank[root_y]:
        parent[root_y] = root_x
    else:
        parent[root_y] = root_x
        rank[root_x] += 1


def kruskal_algorithm(graph):

    edges = []

    # Convert graph dictionary to edge list
    for u in graph:
        for v, weight in graph[u].items():
            if (v, u, weight) not in edges:
                edges.append((u, v, weight))

    # Sort edges by weight
    edges.sort(key=lambda x: x[2])

    parent = {}
    rank = {}

    for vertex in graph:
        parent[vertex] = vertex
        rank[vertex] = 0

    mst = []
    total_weight = 0

    for u, v, weight in edges:
        if find(parent, u) != find(parent, v):
            union(parent, rank, u, v)
            mst.append((u, v, weight))
            total_weight += weight

    return mst, total_weight


mst, min_weight = kruskal_algorithm(graph)

print("Minimum Spanning Tree:", mst)
print("Minimum Weight:", min_weight)
# Out:
# Minimum Spanning Tree: [('B', 'C', 1), ('B', 'D', 1), ('A', 'B', 2), ('D', 'E', 2)]
# Minimum Weight: 6
